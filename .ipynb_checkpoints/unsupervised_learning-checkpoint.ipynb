# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # READING THE DATASET

# %%
df= pd.read_csv('Wine.csv')

# %%
df.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline
# 0   3.92     1065
# 1   3.40     1050
# 2   3.17     1185
# ...

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
rows, colomns= df.shape
print('there are {} rows and {} colomns inside the dataset'.format(rows,colomns))
# Out:
# there are 178 rows and 13 colomns inside the dataset

# %%
# description of the data
df.describe()
# Out:
#           Alcohol  Malic_Acid         Ash  Ash_Alcanity   Magnesium  \
# count  178.000000  178.000000  178.000000    178.000000  178.000000
# mean    13.000618    2.336348    2.366517     19.494944   99.741573
# std      0.811827    1.117146    0.274344      3.339564   14.282484
# min     11.030000    0.740000    1.360000     10.600000   70.000000
# 25%     12.362500    1.602500    2.210000     17.200000   88.000000
# 50%     13.050000    1.865000    2.360000     19.500000   98.000000
# 75%     13.677500    3.082500    2.557500     21.500000  107.000000
# max     14.830000    5.800000    3.230000     30.000000  162.000000
#
#        Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
#checking for null values
df.isna().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# dtype: int64

# %% [markdown]
# There are no null values inside the dataset

# %%
df.hist(figsize=(20,10))
plt.show()

# %% [markdown]
# This is how the data is distributed among the dataset

# %%
#checking for correlation
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), annot= True)
# Out:
# <AxesSubplot:>

# %%
#check for the correlated value
for n in range(len(df.corr().columns)):
    for b in range(n):
        if abs(df.corr().iloc[n,b])> 0.7:
            name= df.corr().columns[n]
            print("highly correlated columns are: ",name)
# Out:
# highly correlated columns are:  Flavanoids
# highly correlated columns are:  OD280

# %%
# here we can drop the column OD280
df= df.drop('OD280',axis= 1)
df.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    Proline
# 0     1065
# 1     1050
# 2     1185
# 3     1480
# 4      735

# %%
df.columns
# Out:
# Index(['Alcohol', 'Malic_Acid', 'Ash', 'Ash_Alcanity', 'Magnesium',
#        'Total_Phenols', 'Flavanoids', 'Nonflavanoid_Phenols',
#        'Proanthocyanins', 'Color_Intensity', 'Hue', 'Proline'],
#       dtype='object')

# %%
# using standard scaler to scale down the values
scaler= StandardScaler()
df[['Alcohol', 'Malic_Acid', 'Ash', 'Ash_Alcanity', 'Magnesium',
       'Total_Phenols', 'Flavanoids', 'Nonflavanoid_Phenols',
       'Proanthocyanins', 'Color_Intensity', 'Hue', 'Proline']]= scaler.fit_transform(df[['Alcohol', 'Malic_Acid', 'Ash', 'Ash_Alcanity', 'Magnesium',
       'Total_Phenols', 'Flavanoids', 'Nonflavanoid_Phenols',
       'Proanthocyanins', 'Color_Intensity', 'Hue', 'Proline']])

# %%
df.head()
# Out:
#     Alcohol  Malic_Acid       Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0  1.518613   -0.562250  0.232053     -1.169593   1.913905       0.808997
# 1  0.246290   -0.499413 -0.827996     -2.490847   0.018145       0.568648
# 2  0.196879    0.021231  1.109334     -0.268738   0.088358       0.808997
# 3  1.691550   -0.346811  0.487926     -0.809251   0.930918       2.491446
# 4  0.295700    0.227694  1.840403      0.451946   1.281985       0.808997
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# 0    1.034819             -0.659563         1.224884         0.251717
# 1    0.733629             -0.820719        -0.544721        -0.293321
# 2    1.215533             -0.498407         2.135968         0.269020
# 3    1.466525             -0.981875         1.032155         1.186068
# 4    0.663351              0.226796         0.401404        -0.319276
#
#         Hue   Proline
# 0  0.362177  1.013009
# 1  0.406051  0.965242
# 2  0.318304  1.395148
# ...

# %% [markdown]
# # CLUSTERING

# %%
#using elbow method to find optimal number of clusters
wcss= []
for i in range(1,11):
    kmeans_model= KMeans(n_clusters=i,init="k-means++",random_state=42)
    kmeans_model.fit(df)
    wcss.append(kmeans_model.inertia_)

# %%
#plotting elbow plot
plt.figure(figsize=(20,10))
plt.plot(range(1,11),wcss,'-o')
plt.title('ELBOW PLOT')
plt.xlabel('number of clusters')
plt.ylabel('WCSS')
plt.show()
